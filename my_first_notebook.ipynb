# %% [markdown]
# Hardware refers to the physical components of a computer system that you can touch and see, such as a monitor, RAM or CPU. Software consists of intangiable instructions, programs, or data that tell the hardware how to operate, such as operating systems or apps. Hardware example: Keyboard. Software example: Paint
